# %%
# !pip install wolframalpha
# Out:
# Collecting wolframalpha
#   Downloading wolframalpha-5.0.0-py3-none-any.whl (7.5 kB)
# Collecting xmltodict (from wolframalpha)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from wolframalpha) (10.1.0)
# Collecting jaraco.context (from wolframalpha)
#   Downloading jaraco.context-4.3.0-py3-none-any.whl (5.3 kB)
# Installing collected packages: xmltodict, jaraco.context, wolframalpha
# Successfully installed jaraco.context-4.3.0 wolframalpha-5.0.0 xmltodict-0.13.0

# %%
import json
from sympy.parsing.mathematica import parse_mathematica
from sympy import *

def read_json_file(file_path):
    try:
        with open(file_path, 'r') as json_file:
            data = json.load(json_file)
            return data
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
        return []

file_path = '/content/ints_ann.json'  # Replace with your actual file path
json_data = read_json_file(file_path)

print(json_data)

# Extract the prompts from the dictionary
prompts_list = [item["prompt"] for item in json_data["annotations"]]

#print(prompts_list)
# Out:
# {'annotations': [{'prompt': 'integral 4*x^1 - 8*x^1 - 1*x^2 - 8*x^2 - 8*x^2 - 2*x^2 - 6*x^2 - 6*x^2 - 2*x^2 + 4*x^3 from 0 to 1'}, {'prompt': 'integral 2*x^2 + 8*x^2 - 6*x^0 + ((3*x^1 - 8*x^3 + 2*x^3 - 6*x^0)/(6*x^2 - 3*x^1 - 3*x^2 - 7*x^2)) from -1 to 1'}, {'prompt': 'integral ((2*x^2 + 8*x^1)/(2*x^2 + 8*x^2 - 6*x^0)) + 1*x^1 + 4*x^1 + ((4*x^3 - 8*x^2 - 4*x^3 + 2*x^3)/(8*x^2 - 5*x^3 + 8*x^1 + 5*x^1)) from -inf to 10'}, {'prompt': 'integral 4*x^1 - 8*x^1 - 1*x^2 - 8*x^2 + 1*x^1 + 4*x^1 + 1*x^2 - 8*x^2 from -10 to 1'}, {'prompt': 'integral 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3 + 7*x^2 + 6*x^0 + 4*x^3 - 4*x^1 - 8*x^2 - 7*x^1 from -1 to 0'}, {'prompt': 'integral 5*x^1 - 4*x^3 - 1*x^2 - 8*x^2 from -10 to 0'}, {'prompt': 'integral 5*x^2 + 2*x^1 + 2*x^2 - 3*x^1 - 2*x^2 + 8*x^1 - 8*x^3 + 5*x^0 + 3*x^1 - 1*x^1 from 0 to 0'}, {'prompt': 'integral 7*x^3 + 7*x^2 + 8*x^2 + 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3 from -inf to 0'}, {'prompt': 'integral 3*x^1 + 8*x^1 - 2*x^2 + 8*x^1 + 4*x^3 + 5*x^2 + 7*x^3 - 1*x^1 from 0 to 0'}, {'prompt': 'integral 5*x^2 + 2*x^1 + 2*x^2 - 3*x^1 - 1*x^1 - 6*x^0 - 6*x^1 + 3*x^1 + 8*x^2 + 4*x^0 - 1*x^1 - 6*x^0 from -inf to 1'}, {'prompt': 'integral 4*x^3 + 6*x^2 - 3*x^1 + 3*x^1 - 7*x^2 from 0 to inf'}, {'prompt': 'integral 1*x^2 + 7*x^2 - 8*x^3 + 5*x^0 + 3*x^1 - 1*x^1 from -inf to 0'}, {'prompt': 'integral 1*x^0 + 2*x^0 + 5*x^1 + 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 - 8*x^2 - 2*x^2 - 6*x^2 - 6*x^2 from -inf to 1'}, {'prompt': 'integral 1*x^2 + 7*x^2 + 4*x^0 + 2*x^2 - 1*x^1 - 5*x^2 - 7*x^3 + 7*x^2 + 8*x^2 from 0 to inf'}, {'prompt': 'integral 7*x^2 - 7*x^3 + 2*x^2 + 8*x^2 - 6*x^0 - 8*x^1 - 1*x^1 from -1 to 0'}, {'prompt': 'integral 8*x^1 + 3*x^1 - ((1*x^2 - 1*x^1 - 8*x^2)/(7*x^2 + 8*x^3 - 8*x^2 + 6*x^2)) + 7*x^2 - 2*x^3 + 2*x^0 from -1 to inf'}, {'prompt': 'integral 4*x^1 - 8*x^1 - 1*x^2 - 8*x^2 + 1*x^1 + 4*x^1 + 1*x^2 - 8*x^2 from 0 to 0'}, {'prompt': 'integral 7*x^2 - 2*x^3 + 2*x^0 + 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3 from -inf to 10'}, {'prompt': 'integral 8*x^1 + 3*x^1 - 3*x^1 + 3*x^1 - 7*x^2 - ((7*x^2 - 2*x^3 + 2*x^0)/(8*x^2 - 1*x^2)) from 0 to inf'}, {'prompt': 'integral 1*x^2 + 7*x^2 - 5*x^1 + 4*x^1 + 8*x^2 - 5*x^3 + 8*x^1 + 5*x^1 + 1*x^2 - 8*x^2 from 0 to 1'}, {'prompt': 'integral 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3 - 5*x^1 - 4*x^3 from -10 to 10'}, {'prompt': 'integral ((7*x^2 - 2*x^3 + 2*x^0)/(8*x^2 - 1*x^2)) + 8*x^2 - 5*x^0 - 6*x^2 - 1*x^2 - 8*x^2 + 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3 from -10 to 1'}, {'prompt': 'integral 7*x^2 - 7*x^3 + 2*x^2 + 8*x^2 - 6*x^0 - 8*x^1 - 1*x^1 from -inf to 0'}, {'prompt': 'integral 7*x^2 + 8*x^3 - 8*x^2 + 6*x^2 + 4*x^3 + 8*x^1 + 7*x^2 + 8*x^2 - 2*x^2 - 6*x^2 - 6*x^2 from 0 to 0'}, {'prompt': 'integral 1*x^2 + 7*x^2 + ((2*x^0 + 8*x^2 + 7*x^3)/(3*x^1 + 3*x^1 - 7*x^2)) + 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 + 6*x^0 + 5*x^0 from 0 to 1'}, {'prompt': 'integral 7*x^2 - 8*x^2 + ((8*x^2 + 3*x^1 - 8*x^2 + 2*x^2)/(1*x^0 + 7*x^2)) - 7*x^2 + 8*x^2 from -1 to 10'}, {'prompt': 'integral 7*x^2 + 8*x^2 + 8*x^1 - 1*x^1 + 1*x^2 - 8*x^2 - 3*x^1 + 3*x^1 - 7*x^2 from -10 to inf'}, {'prompt': 'integral 5*x^2 + 7*x^2 - 3*x^2 - 8*x^1 - 8*x^1 - 1*x^1 + 3*x^1 - 8*x^3 + 2*x^3 - 6*x^0 - 6*x^2 + 1*x^2 - 2*x^1 from -inf to 0'}, {'prompt': 'integral ((2*x^2 + 8*x^1)/(2*x^2 + 8*x^2 - 6*x^0)) + ((3*x^1 + 4*x^0 - 8*x^2)/(3*x^0 + 7*x^0)) + 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 from -1 to 0'}, {'prompt': 'integral 2*x^2 + 8*x^1 + 4*x^1 - 8*x^1 - 1*x^2 - 8*x^2 - ((3*x^1 - 8*x^3 + 2*x^3 - 6*x^0)/(6*x^2 - 3*x^1 - 3*x^2 - 7*x^2)) from -1 to inf'}, {'prompt': 'integral 5*x^2 + 7*x^2 - 3*x^2 - 8*x^1 + 7*x^2 + 8*x^3 - 8*x^2 + 6*x^2 from -inf to inf'}, {'prompt': 'integral 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 - 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 + ((3*x^1 - 8*x^3 + 2*x^3 - 6*x^0)/(6*x^2 - 3*x^1 - 3*x^2 - 7*x^2)) from -1 to 1'}, {'prompt': 'integral 8*x^1 - 1*x^1 + 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 from -inf to 0'}, {'prompt': 'integral 8*x^3 + 2*x^2 + 1*x^2 + 1*x^1 + 4*x^1 - 8*x^2 - 5*x^0 - 6*x^2 from -10 to inf'}, {'prompt': 'integral 7*x^2 - 2*x^3 + 2*x^0 + 4*x^3 - 8*x^2 - 4*x^3 +  ...

# %% [markdown]
# ## **Derivatives**

# %%
import wolframalpha
import requests
import os
import urllib.parse

# App id obtained by the above steps
app_id = 'XTJKXE-UV98JR6EKE'

# Instance of wolf ram alpha
# client class
client = wolframalpha.Client(app_id)

result_list = []
alternate_list = []

for i in range(len(prompts_list)):
  alternate_results = []
  prompt = prompts_list[i]
  print(prompt)
  query_url = f"http://api.wolframalpha.com/v2/query?" \
            f"appid={app_id}" \
            f"&input={prompt}" \
            f"&format=plaintext" \
            f"&output=json"

  r = requests.get(query_url).json()

#  print(f"Result: {r}")


  data = r["queryresult"]["pods"][0]["subpods"][0]
  plaintext = data["plaintext"]

  if(r["queryresult"]["numpods"]>1):
    for k in range(len(r["queryresult"]["pods"])):
      title = r["queryresult"]["pods"][k]["title"]

      if(title == "Alternate forms" or title == "Alternate form"):
        alternate_data = r["queryresult"]["pods"][k]["subpods"]

        for j in range(len(alternate_data)):
          alternate_results.append(alternate_data[j]["plaintext"])

  # Split the expression at the equals sign
  parts = plaintext.split("=")

  print(f"Result: {parts[1].strip()}")
  print(f"Alternate forms: {alternate_results}")
  alternate_list.append(alternate_results)
  result_list.append( parts[1].strip())

#print(result_list)
#print(alternate_list)
# Out:
# derivative of 1*x^2 + 7*x^2 + 4*x^0 + 2*x^2 - 1*x^1 - 5*x^2 - 7*x^3 + 7*x^2 + 8*x^2
# Result: -2744 x^6 + 336 x^5 - 10 x - 1
# Alternate forms: ['x ((336 - 2744 x) x^4 - 10) - 1', '-2 x (28 (49 x - 6) x^4 + 5) - 1']
# derivative of 1*x^2 + 5*x^1 - 7*x^1 + 6*x^0 + ((2*x^3 - 8*x^3)/(3*x^1 - 6*x^1 - 8*x^1)) + 1*x^2 - 8*x^2
# Result: -(1260 x^4)/11 + 15 x^2 - 16 x
# Alternate forms: ['-1/11 x (1260 x^3 - 165 x + 176)', 'x (x (15 - (1260 x^2)/11) - 16)']
# derivative of 2*x^3 + 5*x^0 - 2*x^2 + 8*x^1 - 7*x^2 + 8*x^2
# Result: -2 x^2 (112 x + 9)
# Alternate forms: ['(-224 x - 18) x^2']
# derivative of 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3 + 3*x^1 - 2*x^2 - 3*x^2 - 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 - 1*x^2 + 7*x^2
# Result: -168 x^6 - 120 x^4 - 28 x^3 + 12 x^2 - 26 x - 5
# Alternate forms: ['-2 x (2 x (x (42 x^3 + 30 x + 7) - 3) + 13) - 5', 'x (x (x (x (-168 x^2 - 120) - 28) + 12) - 26) - 5']
# derivative of 7*x^2 + 8*x^2 + 8*x^1 - 1*x^1 + 1*x^2 - 8*x^2 - 3*x^1 + 3*x^1 - 7*x^2
# Result: x (2240 x^3 - 3 x - 48)
# Alternate forms: ['x (x (2240 x^2 - 3) - 48)']

# %%
# Access the derivative results
i=0
for annotation in json_data["annotations"]:
    annotation["derivative_result"] = str(result_list[i])
    annotation["alternate_forms"] = alternate_list[i]
    i=i+1
print(json_data)
# Save the updated JSON data to a file
with open("dev_ann_result.json", "w") as json_file:
    json.dump(json_data, json_file, indent=4)

print("Updated JSON data saved to 'derivative_result_data.json'")
# Out:
# {'annotations': [{'prompt': 'derivative of 1*x^2 + 7*x^2 + 4*x^0 + 2*x^2 - 1*x^1 - 5*x^2 - 7*x^3 + 7*x^2 + 8*x^2', 'derivative_result': '-2744 x^6 + 336 x^5 - 10 x - 1', 'alternate_forms': ['x ((336 - 2744 x) x^4 - 10) - 1', '-2 x (28 (49 x - 6) x^4 + 5) - 1']}, {'prompt': 'derivative of 1*x^2 + 5*x^1 - 7*x^1 + 6*x^0 + ((2*x^3 - 8*x^3)/(3*x^1 - 6*x^1 - 8*x^1)) + 1*x^2 - 8*x^2', 'derivative_result': '-(1260 x^4)/11 + 15 x^2 - 16 x', 'alternate_forms': ['-1/11 x (1260 x^3 - 165 x + 176)', 'x (x (15 - (1260 x^2)/11) - 16)']}, {'prompt': 'derivative of 2*x^3 + 5*x^0 - 2*x^2 + 8*x^1 - 7*x^2 + 8*x^2', 'derivative_result': '-2 x^2 (112 x + 9)', 'alternate_forms': ['-224 x^3 - 18 x^2']}, {'prompt': 'derivative of 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3 + 3*x^1 - 2*x^2 - 3*x^2 - 5*x^1 - 6*x^0 - 3*x^2 + 8*x^3 - 1*x^2 + 7*x^2', 'derivative_result': '-168 x^6 - 120 x^4 - 28 x^3 + 12 x^2 - 26 x - 5', 'alternate_forms': ['-2 x (2 x (x (42 x^3 + 30 x + 7) - 3) + 13) - 5', 'x (x (x (x (-168 x^2 - 120) - 28) + 12) - 26) - 5']}, {'prompt': 'derivative of 7*x^2 + 8*x^2 + 8*x^1 - 1*x^1 + 1*x^2 - 8*x^2 - 3*x^1 + 3*x^1 - 7*x^2', 'derivative_result': 'x (2240 x^3 - 3 x - 48)', 'alternate_forms': ['2240 x^4 - 3 x^2 - 48 x']}, {'prompt': 'derivative of 2*x^2 + 8*x^1 - ((3*x^1 - 2*x^2 - 3*x^2)/(4*x^3 + 8*x^1 + 7*x^2))', 'derivative_result': '(10752 x^8 - 20 x + 15)/(224 x^6)', 'alternate_forms': ['15/(224 x^6) - 5/(56 x^5) + 48 x^2']}, {'prompt': 'derivative of ((1*x^1 + 3*x^1)/(5*x^1 - 8*x^3)) + 3*x^1 - 2*x^2 - 3*x^2 + 8*x^1 - 1*x^1', 'derivative_result': '-(4608 x^6 + 256 x^5 - 5696 x^4 - 320 x^3 + 1720 x^2 + 10 x + 25)/(5 - 8 x^2)^2', 'alternate_forms': ['2 x (45/(5 - 8 x^2)^2 - 36 x - 2) - 1', '-72 x^2 + (90 x)/(8 x^2 - 5)^2 - 4 x - 1', '(-4608 x^6 - 256 x^5 + 5696 x^4 + 320 x^3 - 1720 x^2 - 10 x - 25)/(8 x^2 - 5)^2']}, {'prompt': 'derivative of 8*x^2 + 3*x^1 - 8*x^2 + 2*x^2 - ((2*x^2 + 8*x^1)/(2*x^2 + 8*x^2 - 6*x^0)) - 5*x^2 + 2*x^1 + 2*x^2 - 3*x^1', 'derivative_result': '-100 x^4 - 64 x^3 + (256 x^6)/(8 x^4 - 3)^2 + 24 (1/(3 - 8 x^4) + 3) x^2 - 3', 'alternate_forms': ['-100 x^4 - 64 x^3 + ((8 (8 x^4 + 9))/(8 x^4 - 3)^2 + 72) x^2 - 3', '-4 (25 x + 16) x^3 + 8 (12/(3 - 8 x^4)^2 + 1/(8 x^4 - 3) + 9) x^2 - 3', '-100 x^4 - 64 x^3 + 72 x^2 + (8 x^2)/(8 x^4 - 3) + (96 x^2)/(8 x^4 - 3)^2 - 3']}, {'prompt': 'derivative of 7*x^2 + 6*x^0 + 4*x^3 - 4*x^1 + 4*x^3 - 8*x^2 - 4*x^3 + 2*x^3', 'derivative_result': '-8 x (6 x^4 - 105 x^3 + 8 x^2 + 2)', 'alternate_forms': ['-8 x ((3 x (2 x - 35) + 8) x^2 + 2)', 'x (x^2 ((840 - 48 x) x - 64) - 16)']}, {'prompt': 'derivative of 7*x^2 + 8*x^2 + 8*x^1 - 1*x^1 + 1*x^2 - 8*x^2 - 3*x^1 + 3*x^1 - 7*x^2', 'derivative_result': 'x (2240 x^3 - 3 x - 48)', 'alternate_forms': ['2240 x^4 - 3 x^2 - 48 x']}, {'prompt': 'derivative of 1*x^2 + 7*x^2 + 4*x^0 + 2*x^2 - 1*x^1 - 5*x^2 - 7*x^3 + 7*x^2 + 8*x^2', 'derivative_result': '-2744 x^6 + 336 x^5 - 10 x - 1', 'alternate_forms': ['x ((336 - 2744 x) x^4 - 10) - 1', '-2 x (28 (49 x - 6) x^4 + 5) - 1']}, {'prompt': 'derivative of 3*x^1 + 8*x^1 - 2*x^2 + 8*x^1 + 4*x^3 + 5*x^2 + 7*x^3 - 1*x^1', 'derivative_result': '-24640 x^10 + 48 x - 1', 'alternate_forms': ['x≈0.0208333', 'x≈0.497485']}, {'prompt': 'derivative of 7*x^2 + 8*x^3 - 8*x^2 + 6*x^2 + 7*x^2 - 7*x^3 + ((1*x^1 + 3*x^1)/(5*x^1 - 8*x^3))', 'derivative_result': '7 x^4 (-15/(5 x - 8 x^3) + (3 (5 - 24 x^2) x)/(5 x - 8 x^3)^2 - 288 x + 40)', 'alternate_forms': ['7/4 x (32 (5 - 36 x) x^3 - 75/(5 - 8 x^2)^2 + 3)', '-2016 x^5 + 280 x^4 - (525 x)/(4 (8 x^2 - 5)^2) + (21 x)/4', '-2016 x^5 + 280 x^4 + (84 (4 x^2 - 5) x^3)/(8 x^2 - 5)^2']}, {'prompt': 'derivative of 5*x^2 + 7*x^2 - 3*x^2 - 8*x^1 - 8*x^1 - 1*x^1 + 3*x^1 - 8*x^3 + 2*x^3 - 6*x^0 - 6*x^2 + 1*x^2 - 2*x^1', 'derivative_result': '-2 (48 x^5 - 58 x^3 + 6 x + 9)', 'alternate_forms': ['-96 x^5 + 116 x^3 - 12 x - 18']}, {'prompt': 'derivative of 8*x^3 + 2*x^2 + 1*x^2 - ((8*x^2 + 3*x^1 - 8*x^2 + 2*x^2)/(1*x^0 + 7*x^2)) + 5*x^1 - 4*x^3', 'derivative_result': '4/7 x (196 x^5 + 39 x - 60)', 'alterna ...
# Updated JSON data saved to 'derivative_result_data.json'

# %%
from google.colab import files
files.download('dev_ann_result.json')
